# %% [markdown]
# ## Twitter Data Cleaning in Python

# %%
# !pip install snscrape
# Out:
# Requirement already satisfied: snscrape in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (0.4.3.20220106)
# Requirement already satisfied: beautifulsoup4 in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (from snscrape) (4.11.1)
# Requirement already satisfied: lxml in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (from snscrape) (4.8.0)
# Requirement already satisfied: filelock in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (from snscrape) (3.6.0)
# Requirement already satisfied: requests[socks] in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (from snscrape) (2.27.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (from beautifulsoup4->snscrape) (2.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (from requests[socks]->snscrape) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (from requests[socks]->snscrape) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (from requests[socks]->snscrape) (1.26.9)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\joyce\anaconda_new\anaconda22\new folder\lib\site-packages (from requests[socks]->snscrape) (1.7.1)

# %%
#Import libraries
import pandas as pd
from time import sleep
from tqdm import tqdm
import re
import nltk
import snscrape.modules.twitter as sntwitter

# %%
#Add query
query = "(#PeterObi OR #PeterObi2023) until:2022-06-26 since:2022-05-01"
tweets =[]
limit = 30000


for tweet in sntwitter.TwitterHashtagScraper(query).get_items():
    if len(tweets)== limit:
        break
    else:
        tweets.append([tweet.date, tweet.url, tweet.user.username, tweet.sourceLabel, tweet.user.location, tweet.content, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount])
#Load to DataFrame  
        df1 = pd.DataFrame(tweets, columns = ['Date', 'TweetUrl', 'User', 'Source', 'Location', 'Tweet', 'Likes_Count', 'Retweet_Count', 'Quote_Count', 'Reply_Count'])
#Load to csv file                                               
df1.to_csv('snscrape_election.csv')

# %%
df1.head()
# Out:
#                        Date  \
# 0 2022-06-25 23:58:50+00:00
# 1 2022-06-25 23:57:29+00:00
# 2 2022-06-25 23:55:55+00:00
# 3 2022-06-25 23:51:26+00:00
# 4 2022-06-25 23:50:59+00:00
#
#                                             TweetUrl           User  \
# 0  https://twitter.com/Plato48466760/status/15408...  Plato48466760
# 1  https://twitter.com/AsHiiR_/status/15408466728...        AsHiiR_
# 2  https://twitter.com/ObiSupport/status/15408462...     ObiSupport
# 3  https://twitter.com/cleoterria/status/15408451...     cleoterria
# 4  https://twitter.com/humanfactorz/status/154084...   humanfactorz
#
#                 Source           Location  \
# 0  Twitter for Android
# 1   Twitter for iPhone  All over Nigeria
# 2   Twitter for iPhone            Nigeria
# 3  Twitter for Android
# 4  Twitter for Android             🌎  🇺🇸
#
#                                                Tweet  Likes_Count  \
# 0  We understand your relationship with @segalink...            1
# 1  If you're an #OBIdient in Niger state hit me u...            0
# 2  2023: Voting #PeterObi, The New Narrative In N...           32
# 3  tonight was another failed gas lighting attemp...            0
# 4  BUNDLE OF INTEGRITY #PeterObiForPresident2023 ...            0
#
#    Retweet_Count  Quote_Count  Reply_Count
# 0              0            0            0
# 1              0            0            0
# 2             12            2            0
# 3              0            0            0
# 4              0            0            0

# %%
#Location Count
df1["Location"].value_counts()[:60]
# Out:
#                                   8293
# Nigeria                           3767
# Lagos, Nigeria                    2949
# Abuja, Nigeria                    1042
# Federal Capital Territory, Nig     386
# Lagos                              356
# Port Harcourt, Nigeria             272
# Enugu, Nigeria                     245
# Abuja                              245
# Earth                              193
# Lagos, Nigeria.                    174
# Lagos Nigeria                      166
# Nigeria                            165
# United States                      131
# EARTH                              127
# Owerri, Nigeria                    115
# Lagos,Nigeria                      111
# Africa                             108
# Jos, Nigeria                       108
# Ibadan, Nigeria                    106
# Around the world                   103
# London, England                    102
# Uyo, Nigeria                        97
# Lekki, Nigeria                      95
# Kano, Nigeria                       93
# Benin-City, Nigeria                 86
# Calabar, Nigeria                    76
# New Hampshire, USA                  75
# United Kingdom                      74
# Port Harcourt                       73
# Anambra, Nigeria                    72
# Turin, Piedmont                     68
# Delta, Nigeria                      66
# nigeria                             64
# NIGERIA                             63
# MY PALACE                           61
# Awka, Nigeria                       58
# England, United Kingdom             57
# Canada                              57
# Rivers, Nigeria                     57
# New York, USA                       55
# lagos                               55
# Kaduna, Nigeria                     55
# Lagos                               55
# Asaba, Nigeria                      54
# Ikeja, Nigeria                      52
# Onitsha, Nigeria                    49
# The next Street                     49
# Worldwide                           47
# Heaven                              46
# Warri, Nigeria                      45
# 🇳🇬                                  45
# Abuja                               45
# anywhere and everywhere..           44
# Victoria Island, Nigeria            43
# Fellow Global Citizen               43
# California, USA                     41
# Imo, Nigeria                        39
# Global                              39
# Next Door                           38
# Name: Location, dtype: int64

# %%
#Stop words present in the library
stopwords = nltk.corpus.stopwords.words('english')
stopwords[0:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
#defining the function to remove stopwords from tokenized text
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output

# %%
#applying the function
no_stopwords= lower.apply(lambda x:remove_stopwords(x))

# %%
#Load DataFrame
df = pd.read_csv("snscrape_election.csv",index = False)

# %%
df.head()
# Out:
#    Unnamed: 0                       Date  \
# 0           0  2022-06-25 23:58:50+00:00
# 1           1  2022-06-25 23:57:29+00:00
# 2           2  2022-06-25 23:55:55+00:00
# 3           3  2022-06-25 23:51:26+00:00
# 4           4  2022-06-25 23:50:59+00:00
#
#                                             TweetUrl           User  \
# 0  https://twitter.com/Plato48466760/status/15408...  Plato48466760
# 1  https://twitter.com/AsHiiR_/status/15408466728...        AsHiiR_
# 2  https://twitter.com/ObiSupport/status/15408462...     ObiSupport
# 3  https://twitter.com/cleoterria/status/15408451...     cleoterria
# 4  https://twitter.com/humanfactorz/status/154084...   humanfactorz
#
#                 Source           Location  \
# 0  Twitter for Android                NaN
# 1   Twitter for iPhone  All over Nigeria
# 2   Twitter for iPhone            Nigeria
# 3  Twitter for Android                NaN
# 4  Twitter for Android             🌎  🇺🇸
#
#                                                Tweet  Likes_Count  \
# 0  We understand your relationship with @segalink...            1
# 1  If you're an #OBIdient in Niger state hit me u...            0
# 2  2023: Voting #PeterObi, The New Narrative In N...           32
# 3  tonight was another failed gas lighting attemp...            0
# 4  BUNDLE OF INTEGRITY #PeterObiForPresident2023 ...            0
#
#    Retweet_Count  Quote_Count  Reply_Count
# 0              0            0            0
# 1              0            0            0
# 2             12            2            0
# 3              0            0            0
# 4              0            0            0

# %%
#Drop duplicate
df= df.drop_duplicates("Tweet", keep ="first")
df
# Out:
#        Unnamed: 0                       Date  \
# 0               0  2022-06-25 23:58:50+00:00
# 1               1  2022-06-25 23:57:29+00:00
# 2               2  2022-06-25 23:55:55+00:00
# 3               3  2022-06-25 23:51:26+00:00
# 4               4  2022-06-25 23:50:59+00:00
# ...           ...                        ...
# 29994       29994  2022-06-14 14:18:56+00:00
# 29995       29995  2022-06-14 14:18:28+00:00
# 29997       29997  2022-06-14 14:18:02+00:00
# 29998       29998  2022-06-14 14:17:37+00:00
# 29999       29999  2022-06-14 14:17:35+00:00
#
#                                                 TweetUrl           User  \
# 0      https://twitter.com/Plato48466760/status/15408...  Plato48466760
# 1      https://twitter.com/AsHiiR_/status/15408466728...        AsHiiR_
# 2      https://twitter.com/ObiSupport/status/15408462...     ObiSupport
# 3      https://twitter.com/cleoterria/status/15408451...     cleoterria
# 4      https://twitter.com/humanfactorz/status/154084...   humanfactorz
# ...                                                  ...            ...
# 29994  https://twitter.com/acmelegend/status/15367148...     acmelegend
# 29995  https://twitter.com/onyiforlife/status/1536714...    onyiforlife
# 29997  https://twitter.com/RunMila1/status/1536714585...       RunMila1
# 29998  https://twitter.com/Kaynuel_/status/1536714480...       Kaynuel_
# 29999  https://twitter.com/NFPJNig/status/15367144698...        NFPJNig
#
#                     Source             Location  \
# 0      Twitter for Android                  NaN
# 1       Twitter for iPhone    All over Nigeria
# 2       Twitter for iPhone              Nigeria
# 3      Twitter for Android                  NaN
# 4      Twitter for Android               🌎  🇺🇸
# ...                    ...                  ...
# 29994  Twitter for Android              NIGERIA
# 29995  Twitter for Android  Benin-City, Nigeria
# 29997   Twitter for iPhone                  NaN
# 29998  Twitter for Android                  NaN
# 29999   Twitter for iPhone             Nigeria
#
#                                                    Tweet  Likes_Count  \
# 0      We understand your relationship with @segalink...            1
# 1      If you're an #OBIdient in Niger state hit me u...            0
# 2      2023: Voting #PeterObi, The New Narrative In N...           32
# 3      tonight was another failed gas lighting attemp...            0
# 4      BUNDLE OF INTEGRITY #PeterObiForPresident2023 ...            0
# ...                                                  ...          ...
# 29994                   @PeterObi I stand with #PeterObi            0
# 29995  @PeterObi My president departed for Egypt 🇪🇬 S...            4
# 29997  @_SirWilliam_ @PeterObi Thank you William!!! #...            0
# 29998  @PeterObi Obidient to the core! #PeterObi #Pet...            0
# 29999  Breaking News - we demand a free and fair elec...            5
#
#        Retweet_Count  Quote_Count  Reply_Count
# 0                  0            0            0
# 1                  0            0            0
# 2                 12            2            0
# 3                  0            0            0
# 4                  0            0            0
# ...              ...          ...          ...
# 29994              0            0            0
# 29995              2            0            0
# 29997              0            0            0
# 29998              0            0            0
# 29999              3            2            0
#
# [29804 rows x 11 columns]

# %%
#Load tweet column into a new DataFrame
df1 = df["Tweet"]

# %%
#Load to a CSV file
df1.to_csv("tweet.csv", index = False)
df1 = pd.read_csv("tweet.csv")
df1.head()
# Out:
#                                                Tweet
# 0  We understand your relationship with @segalink...
# 1  If you're an #OBIdient in Niger state hit me u...
# 2  2023: Voting #PeterObi, The New Narrative In N...
# 3  tonight was another failed gas lighting attemp...
# 4  BUNDLE OF INTEGRITY #PeterObiForPresident2023 ...

# %%
df1.head()
# Out:
#                                                Tweet
# 0  We understand your relationship with @segalink...
# 1  If you're an #OBIdient in Niger state hit me u...
# 2  2023: Voting #PeterObi, The New Narrative In N...
# 3  tonight was another failed gas lighting attemp...
# 4  BUNDLE OF INTEGRITY #PeterObiForPresident2023 ...

# %% [markdown]
# #### Remove punctuation mark

# %%
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree
#storing the puntuation free text
puntuation_free= df1["Tweet"].apply(lambda x:remove_punctuation(x))
puntuation_free.head()
# Out:
# 0    We understand your relationship with segalink ...
# 1    If youre an OBIdient in Niger state hit me up ...
# 2    2023 Voting PeterObi The New Narrative In Nort...
# 3    tonight was another failed gas lighting attemp...
# 4    BUNDLE OF INTEGRITY PeterObiForPresident2023 P...
# Name: Tweet, dtype: object

# %% [markdown]
# #### Convert to Lowercase

# %%
#Lowercasing all the letters
lower = puntuation_free.apply(lambda x: x.lower())
lower.head()
# Out:
# 0    we understand your relationship with segalink ...
# 1    if youre an obidient in niger state hit me up ...
# 2    2023 voting peterobi the new narrative in nort...
# 3    tonight was another failed gas lighting attemp...
# 4    bundle of integrity peterobiforpresident2023 p...
# Name: Tweet, dtype: object

# %%
df1["cleaned_tweet"] = lower

# %%
df1
# Out:
#                                                    Tweet  \
# 0      We understand your relationship with @segalink...
# 1      If you're an #OBIdient in Niger state hit me u...
# 2      2023: Voting #PeterObi, The New Narrative In N...
# 3      tonight was another failed gas lighting attemp...
# 4      BUNDLE OF INTEGRITY #PeterObiForPresident2023 ...
# ...                                                  ...
# 29799                   @PeterObi I stand with #PeterObi
# 29800  @PeterObi My president departed for Egypt 🇪🇬 S...
# 29801  @_SirWilliam_ @PeterObi Thank you William!!! #...
# 29802  @PeterObi Obidient to the core! #PeterObi #Pet...
# 29803  Breaking News - we demand a free and fair elec...
#
#                                            cleaned_tweet
# 0      we understand your relationship with segalink ...
# 1      if youre an obidient in niger state hit me up ...
# 2      2023 voting peterobi the new narrative in nort...
# 3      tonight was another failed gas lighting attemp...
# 4      bundle of integrity peterobiforpresident2023 p...
# ...                                                  ...
# 29799                     peterobi i stand with peterobi
# 29800  peterobi my president departed for egypt 🇪🇬 sa...
# 29801  sirwilliam peterobi thank you william peterobi...
# 29802  peterobi obidient to the core peterobi peterob...
# 29803  breaking news  we demand a free and fair elect...
#
# [29804 rows x 2 columns]

# %% [markdown]
# #### Replace Emoji with text
# Load pickle file and replace emoji with text

# %%
import pickle
with open("emoji_dict.pkl","rb") as f:
    Emoji_dict = pickle.load(f)
Emoji_Dict = {v: k for k, v in Emoji_Dict.items()}

def convert_emojis_to_word(text):
    for emot in Emoji_Dict:
        text = re.sub(r'('+emot+')', "_".join(Emoji_Dict[emot].replace(",","").replace(":","").split()), text)
    return text

# %%
df1["cleaned_tweet"]= data[column].progress_apply(lambda text: convert_emoticons(str(text)))

# %%
df1.head()

# %%
for tweet in df1["cleaned_tweet"]:
    print(tweet)
